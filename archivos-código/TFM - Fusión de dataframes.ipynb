# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
os.chdir("D://Master//10. TFM//Data")

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Vamos a cargar todos los datasets del e-Commerce

# %% [markdown]
# #### Customers

# %%
customers = pd.read_csv("customers.csv")

# %%
customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# ...

# %% [markdown]
# #### Geolocation

# %%
geolocation = pd.read_csv("geolocation.csv")

# %%
geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# ...

# %% [markdown]
# #### Order_items

# %%
order_items = pd.read_csv("order_items.csv")

# %%
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# ...

# %% [markdown]
# #### Order_payments

# %%
order_payments = pd.read_csv("order_payments.csv")

# %%
order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# #### Order_reviews

# %%
order_reviews = pd.read_csv("order_reviews.csv")

# %%
order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# #### Orders

# %%
orders = pd.read_csv("orders.csv")

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %% [markdown]
# #### Products

# %%
products = pd.read_csv("products.csv")

# %%
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %% [markdown]
# #### Sellers

# %%
sellers = pd.read_csv("sellers.csv")

# %%
sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %% [markdown]
# Observamos que hay varios campos interesantes en las diferentes tablas para poder formar un único dataset con datos de pedidos y clientes.
#
# - customer_id
# - customer_zip_code_prefix
# - customer_city
# - customer_state
# - order_id
# - price
# - freight_value
# - payment_type
# - payment_value (debe ser igual a price + freight_value)
# - product_id (aquí puede haber varios id dentro de un mismo pedido pero teóricamente podemos sacarlos de la tabla order_items)
# - product_category_name
# - order_status
# - order_purchase_timestamp
# - order_approved_at
# - review_id
# - review_score

# %% [markdown]
# ## Fusión Dataframes

# %%
df_0 = pd.merge(customers,orders, on="customer_id", how="inner") 
df_0
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state  \
# ...

# %%
df_1 = df_0.merge(order_payments, on="order_id", how="inner")
df_1
# Out:
#                              customer_id                customer_unique_id  \
# 0       06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1       18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2       4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3       b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4       4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                  ...                               ...
# 103881  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 103882  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 103883  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 103884  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 103885  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
# ...

# %% [markdown]
# Observamos que al unir ambos dataframes, ha aumentado el número de filas, por lo que puede suponer que existen valores duplicados en nuestra columna clave 'order_id'

# %%
# Encuentra los valores duplicados en la columna 'id_customer' de df1
duplicados_df0 = df_0[df_0['order_id'].duplicated(keep=False)]

# Encuentra los valores duplicados en la columna 'id_customer' de df2
duplicados_order_payments = order_payments[order_payments['order_id'].duplicated(keep=False)]

# Imprime la cantidad de duplicados en cada DataFrame
print("Duplicados en df_0:", len(duplicados_df0))
print("Duplicados en order_payments:", len(duplicados_order_payments))
# Out:
# Duplicados en df_0: 0
# Duplicados en order_payments: 7407

# %% [markdown]
# Efectivamente, el dataframe 'order_payments' contiene 7407 valores duplicados. Esto puede debersea que se han utilizado varios métodos de pago en un mismo pedido. Vamos a comprobarlo:

# %%
duplicados_order_payments = order_payments[order_payments['order_id'].duplicated(keep=False)].sort_values(by='order_id')
duplicados_order_payments.head()
# Out:
#                                order_id  payment_sequential payment_type  \
# 80856  0016dfedd97fc2950e388d2971d718c7                   2      voucher
# 89575  0016dfedd97fc2950e388d2971d718c7                   1  credit_card
# 20036  002f19a65a2ddd70a090297872e6d64e                   1      voucher
# 98894  002f19a65a2ddd70a090297872e6d64e                   2      voucher
# 30155  0071ee2429bc1efdc43aa3e073a5290e                   2      voucher
#
#        payment_installments  payment_value
# 80856                     1          17.92
# 89575                     5          52.63
# 20036                     1          44.11
# 98894                     1          33.18
# 30155                     1          92.44

# %% [markdown]
# Comprobamos que los pedidos duplicados se deben a que un cliente ha utilizado varios métodos de pago en un mismo pedido.
#
# Para simplicar nuestro estudio, vamos a agrupar los pedidos duplicados en un único método de pago llamado "Varios"

# %%
df_agrupado = df_1.groupby('order_id').agg({'payment_type': ', '.join, 'payment_value': 'sum'}).reset_index()

# %%
df_agrupado['payment_type'] = df_agrupado['payment_type'].apply(lambda x: 'varios' if ', ' in x else x)

# %%
df_agrupado.head()
# Out:
#                            order_id payment_type  payment_value
# 0  00010242fe8c5a6d1ba2dd792cb16214  credit_card          72.19
# 1  00018f77f2f0320c557190d7a144bdd3  credit_card         259.83
# 2  000229ec398224ef6ca0657da4fc703e  credit_card         216.87
# 3  00024acbcdf0a6daa1e931b038114c75  credit_card          25.78
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  credit_card         218.04

# %%
df_1[df_1['order_id'] == '0016dfedd97fc2950e388d2971d718c7']
# Out:
#                             customer_id                customer_unique_id  \
# 76103  2c8b917c5d7dd720ebe36a5ed3b501ec  33febb33a42a35f5826a22584b127f9d
# 76104  2c8b917c5d7dd720ebe36a5ed3b501ec  33febb33a42a35f5826a22584b127f9d
#
#        customer_zip_code_prefix customer_city customer_state  \
# 76103                     45860   canavieiras             BA
# 76104                     45860   canavieiras             BA
#
#                                order_id order_status order_purchase_timestamp  \
# 76103  0016dfedd97fc2950e388d2971d718c7    delivered      2017-04-28 19:54:40
# 76104  0016dfedd97fc2950e388d2971d718c7    delivered      2017-04-28 19:54:40
#
#          order_approved_at order_delivered_carrier_date  \
# 76103  2017-04-29 10:05:12          2017-05-16 08:40:49
# 76104  2017-04-29 10:05:12          2017-05-16 08:40:49
#
#       order_delivered_customer_date order_estimated_delivery_date  \
# 76103           2017-05-22 18:32:21           2017-06-01 00:00:00
# ...

# %%
df_agrupado[df_agrupado['order_id'] == '0016dfedd97fc2950e388d2971d718c7']
# Out:
#                             order_id payment_type  payment_value
# 36  0016dfedd97fc2950e388d2971d718c7       varios          70.55

# %% [markdown]
# Tras estas operaciones, hemos conseguido fusionar aquellos pedidos con varios métodos de pago en un método de pago común llamado "varios", además de sumar el total del valor de pago.

# %%
df_2 = df_agrupado.merge(df_0, on="order_id", how="inner")
df_2
# Out:
#                                order_id payment_type  payment_value  \
# 0      00010242fe8c5a6d1ba2dd792cb16214  credit_card          72.19
# 1      00018f77f2f0320c557190d7a144bdd3  credit_card         259.83
# 2      000229ec398224ef6ca0657da4fc703e  credit_card         216.87
# 3      00024acbcdf0a6daa1e931b038114c75  credit_card          25.78
# 4      00042b26cf59d7ce69dfabb4e55b4fd9  credit_card         218.04
# ...                                 ...          ...            ...
# 99435  fffc94f6ce00a00581880bf54a75a037       boleto         343.40
# 99436  fffcd46ef2263f404302a634eb57f7eb       boleto         386.53
# 99437  fffce4705a9662cd70adb13d4a31832d  credit_card         116.85
# 99438  fffe18544ffabc95dfada21779c9644f  credit_card          64.71
# 99439  fffe41c64501cc87c801fd61db3f6244  credit_card          55.79
#
#                             customer_id                customer_unique_id  \
# 0      3ce436f183e68e07877b285a838db11a  871766c5855e863f6eccc05f988b23cb
# ...

# %%
df_3 = df_2.merge(order_items, on="order_id", how="inner")
df_3
# Out:
#                                 order_id payment_type  payment_value  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  credit_card          72.19
# 1       00018f77f2f0320c557190d7a144bdd3  credit_card         259.83
# 2       000229ec398224ef6ca0657da4fc703e  credit_card         216.87
# 3       00024acbcdf0a6daa1e931b038114c75  credit_card          25.78
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  credit_card         218.04
# ...                                  ...          ...            ...
# 112642  fffc94f6ce00a00581880bf54a75a037       boleto         343.40
# 112643  fffcd46ef2263f404302a634eb57f7eb       boleto         386.53
# 112644  fffce4705a9662cd70adb13d4a31832d  credit_card         116.85
# 112645  fffe18544ffabc95dfada21779c9644f  credit_card          64.71
# 112646  fffe41c64501cc87c801fd61db3f6244  credit_card          55.79
#
#                              customer_id                customer_unique_id  \
# ...

# %% [markdown]
# Al unir con el dataframe de order_items volvemos a tener un problema similar al de antes. Hay order_id duplicadas ya que un mismo pedido puede contener distintos productos. Hacemos la comprobación.

# %%
# Encuentra los valores duplicados en la columna 'order_id' de df_3
duplicados_df3 = df_3[df_3['order_id'].duplicated(keep=False)]

# Imprime la cantidad de duplicados en el DataFrame
print("Duplicados en df_3:", len(duplicados_df3))
# Out:
# Duplicados en df_3: 23784

# %%
duplicados_df3.sort_values(by='order_id')
# Out:
#                                 order_id payment_type  payment_value  \
# 13      0008288aa423d2a3f00fcb17cd7d8719       boleto         126.54
# 14      0008288aa423d2a3f00fcb17cd7d8719       boleto         126.54
# 32      00143d0f86d6fbd9f9b38ab440ac16f5  credit_card         109.29
# 33      00143d0f86d6fbd9f9b38ab440ac16f5  credit_card         109.29
# 34      00143d0f86d6fbd9f9b38ab440ac16f5  credit_card         109.29
# ...                                  ...          ...            ...
# 112631  fff8287bbae429a99bb7e8c21d151c41  credit_card         456.28
# 112638  fffb9224b6fc7c43ebb0904318b10b5f       boleto         356.76
# 112639  fffb9224b6fc7c43ebb0904318b10b5f       boleto         356.76
# 112637  fffb9224b6fc7c43ebb0904318b10b5f       boleto         356.76
# 112640  fffb9224b6fc7c43ebb0904318b10b5f       boleto         356.76
#
#                              customer_id                customer_unique_id  \
# ...

# %% [markdown]
# Observamos que se trata de pedidos con varias unidades de un mismo artículo o con varias unidades de distintos artículos.
# Podemos optar por mantener estos pedidos duplicados y tratar de aprovechar los datos de información de los productos de cara a la segmentación.

# %% [markdown]
# A continuación, continuamos fusionando con los otros dataframes.

# %%
df_4 = df_3.merge(products, on="product_id", how="inner")
df_4
# Out:
#                                 order_id payment_type  payment_value  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  credit_card          72.19
# 1       130898c0987d1801452a8ed92a670612       boleto          73.86
# 2       532ed5e14e24ae1f0d735b91524b98b9  credit_card          83.23
# 3       6f8c31653edb8c83e1a739408b5ff750  credit_card          75.07
# 4       7d19f4ef4d04461989632411b7e588b9  credit_card          72.19
# ...                                  ...          ...            ...
# 112642  ffebd80e3291e811c308365936897efd  credit_card         181.10
# 112643  ffee31fb4b5e35c9123608015637c495  credit_card         112.52
# 112644  fff7c4452f050315db1b3f24d9df5fcd  credit_card         756.91
# 112645  fffa82886406ccf10c7b4e35c4ff2788  credit_card         273.92
# 112646  fffe41c64501cc87c801fd61db3f6244  credit_card          55.79
#
#                              customer_id                customer_unique_id  \
# ...

# %%
df_5 = df_4.merge(order_reviews, on="order_id", how="inner")
df_5
# Out:
#                                 order_id payment_type  payment_value  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  credit_card          72.19
# 1       130898c0987d1801452a8ed92a670612       boleto          73.86
# 2       532ed5e14e24ae1f0d735b91524b98b9  credit_card          83.23
# 3       6f8c31653edb8c83e1a739408b5ff750  credit_card          75.07
# 4       7d19f4ef4d04461989632411b7e588b9  credit_card          72.19
# ...                                  ...          ...            ...
# 112364  ffebd80e3291e811c308365936897efd  credit_card         181.10
# 112365  ffee31fb4b5e35c9123608015637c495  credit_card         112.52
# 112366  fff7c4452f050315db1b3f24d9df5fcd  credit_card         756.91
# 112367  fffa82886406ccf10c7b4e35c4ff2788  credit_card         273.92
# 112368  fffe41c64501cc87c801fd61db3f6244  credit_card          55.79
#
#                              customer_id                customer_unique_id  \
# ...

# %%
df_inicial = df_5[['customer_id','customer_zip_code_prefix','customer_city','customer_state','order_id','price','freight_value','payment_type','payment_value','product_id','product_category_name','order_status','order_purchase_timestamp','order_approved_at','review_id','review_score']]
df_inicial
# Out:
#                              customer_id  customer_zip_code_prefix  \
# 0       3ce436f183e68e07877b285a838db11a                     28013
# 1       e6eecc5a77de221464d1c4eaff0a9b64                     75800
# 2       4ef55bf80f711b372afebcb7c715344a                     30720
# 3       30407a72ad8b3f4df4d15369126b20c9                     83070
# 4       91a792fef70ecd8cc69d3c7feb3d12da                     36400
# ...                                  ...                       ...
# 112364  050309b91cc5e04e68841938e7984aaf                     28740
# 112365  11e0f43ab4e2d2c48348dd9332c0ef80                     83065
# 112366  dec8952e97ef6124259c56914fb3569c                     27261
# 112367  a5201e1a6d71a8d21e869151bd5b4085                     59955
# 112368  96d649da0cc4ff33bb408b199d4c7dcf                     18605
#
#                 customer_city customer_state  \
# 0       campos dos goytacazes             RJ
# 1                       jatai             GO
# ...

# %% [markdown]
# Guardamos en csv

# %%
df_inicial.to_csv('df_inicial.csv', index=False)
